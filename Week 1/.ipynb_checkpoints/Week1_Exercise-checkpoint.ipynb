# %% [markdown]
# ## **Problem 1: Print Statements**
# Write a Python program that prints the following two lines in the cell below ⬇️⬇️⬇️:
# 1. Hi, your name, your age and origin.
# 2. Welcome to SRH!

# %% [markdown]
# ## **Problem 2: Print Statements**
# Create variables of the following types in the cell below ⬇️⬇️⬇️:
# - Integer
# - Float
# - String
# - Boolean
# - List (with three numbers)
# - Dictionary (with three keys and corresponding values)
# Then print each variable and its type using the type() function.

# %% [markdown]
# ## **Problem 3: Arithmetic Operations**
# Create two integer variables, a = 15 and b=4 in the cell below ⬇️⬇️⬇️:
# Compute and print:
# - Addition
# - Subtraction
# - Multiplication
# - True Division (/)
# - Floor Division (//)
# - Modulus (%)
# - Exponentiation (**)

# %% [markdown]
# ## **Problem 4: Modulo Understanding**
# Write a program to compute 7 % 3 and show the calculation step as a comment in the cell below ⬇️⬇️⬇️:

# %% [markdown]
# ## **Problem 5: Boolean Comparisons**
# Create variables x= 10 and y=15, then print the results of the following comparisons in the cell below ⬇️⬇️⬇️:
# - x greater than y
# - x smaller than y
# - x equals 10
# - y is not equal to 15
# - x is greater than or equal to 5
# - y is less than or equal to 20

# %% [markdown]
# ## **Problem 6: Boolean and logical operators**
# Let a= 8 and b=12. Compute and print in the cell below ⬇️⬇️⬇️:
# 1. a < 10 and b > 10
# 2. a > 5 or b < 10
# 3. not (a== 8)

# %% [markdown]
# ## **Problem 7: Type Casting (String to Integer and Float)**
# Given s1= "20" and s2 ="3.5", convert them into integer and float, respectively, and print their types in the cell below ⬇️⬇️⬇️:

# %% [markdown]
# ## **Problem 8: Type Casting (Number to String)**
# Given num= 42, convert it to a string and concatenate it with " is the answer" in the cell below ⬇️⬇️⬇️:

# %% [markdown]
# ## **Problem 9: Integer to Boolean**
# Check the boolean values 0, 1, and -5 using the bool () function in the cell below ⬇️⬇️⬇️:

# %% [markdown]
# ## **Problem 10: String to Boolean**
# Check the boolean values of empty string and "Python" in the cell below ⬇️⬇️⬇️:

# %% [markdown]
# ## **Problem 11: Variable Reassignment**
# Assign x=5. Then reassign x=10, print the variable after each assignment, and explain in a comment why this is allowed even if integers are immutable in the cell below ⬇️⬇️⬇️:

# %% [markdown]
# ## **Problem 12: Arithmetic Expression**
# Compute this expression $(5+3) *2^3-4/2$ in the cell below ⬇️⬇️⬇️:

# %% [markdown]
# ## **Problem 13: Banking Transaction**
# In the cell below ⬇️⬇️⬇️, do the following:
# 1. Create a 'balance' variable and declare its value to 1000.0
# 2. Create 'withdrawal_amount' variable and declare its value to "250"
# 3. Convert 'withdrawal_amount' to a float.
# 4. Create a boolean 'can_withdraw'  using only comparison between 'balance' and 'withdrawal_amount'
# 5. Compute the new balance after withdrawal (even if it's negative) and assign it to the 'new_balance' variable.
# 6. Print all variables clearly:
# - "Original balance: ...."
# - "Withdrawal amount:...."
# - "Can withdraw?:...."
# - "New balance:...."

# %% [markdown]
# ## **Problem 14: Student Enrollment**  (Take-home Assignment)
# In the cell below ⬇️⬇️⬇️, do the following:
# 1. Create 'age' variable and declare its value to "19"
# 2. Create 'credits_completed' variable and declare its value to 120
# 3. Convert 'age' to an integer.
# 4. Compute **two booleans** as follows:
# -  'eligible_by_age'=  'age'is greater than or equal to 18
# - 'eligible_by_credits'=  'credits_completed' is greater than or equal to 100
# 5. Create 'eligible_to_enroll' bool variable where 'eligible_by_age' and 'eligible_by_age'
# 6. Print all variables clearly:
# - "Age: ...."
# - "Credits completed:...."
# - "Eligible by age:...."
# - "Eligible by credits:...."
# - "Eligible to enroll:...."

# %% [markdown]
# ## **Problem 15: Mixed Calculation Challenge** (Take-home Assignment)
# In the cell below ⬇️⬇️⬇️, do the following:
# 1. Create the following variables as strings or numbers:
# - a = "14"
# - b = 5.5
# - c= "3"
# 2. Convert all string variables to the correct numeric type
# 3. Compute the following **directly**, using only arithemetic and boolean operations:
# - result1= (a+b) * c
# - result2= (b**c) / a
# - result3= (a*c) % b
# - is_multiple= result1 % 2
# 4. Print all the results clearly with descriptive text.

# %% [markdown]
# ### Now we are done with the exercises of week 1 🎉🎉🎉 ##
# ![Week 1](congrats.jpeg)
# ### After you are done, please submit your notebook on the e-campus. The assignment link will expire in **two** days.
