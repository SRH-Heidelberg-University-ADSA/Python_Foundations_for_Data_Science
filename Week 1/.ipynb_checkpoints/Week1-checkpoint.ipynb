# %% [markdown]
# # Introduction to Python & Programming Concepts
# Python is widely adopted in data science and artificial intelligence applications due to its *expressive syntax*, *extensive ecosystem*, and *strong community support*.
# In practice, famous libraries such as `numpy`, `pandas`, `matplotlib`, etc. are routinely used for numerical computing, data manipulation, visualisation, and machine learning.
# In the upcoming weeks, we will go through these libraries and more in detail.

# %% [markdown]
# # Python Environment Installation
# Setting up a Python environment is essential for running code, data analysis, and machine learning projects.
#
# Below are detailed instructions for installing three popular Python environments: **Anaconda / Jupyter Notebook**, **Visual Studio Code (VS Code)**, and **Google Colab**.
#
# #### 1. Anaconda / Jupyter Notebook
# **Anaconda** is a popular Python distribution that comes with many scientific libraries and tools pre-installed. **Jupyter Notebook** allows you to write and run Python code interactively.
#
# 1. Download **Anaconda** from the official website: [https://www.anaconda.com/products/distribution](https://www.anaconda.com/products/distribution)
# 2. Run the installer and follow the instructions. You may choose to add Anaconda to your system PATH (optional but recommended).
# 3. Open **Anaconda Navigator** from your start menu or applications folder.
# 4. Launch **Jupyter Notebook** via Anaconda Navigator or by typing the following command in your terminal or command prompt:
#    ```bash
#    jupyter notebook
#    ```
# 5. A browser window will open. Create a new Python notebook and run a test command to ensure everything works:
#  ```python
#    print("Hello, Python!")
#    ```
# 6. You can now write, run, and save Python code in cells interactively.
#
#    ---
#
# #### 2. Visual Studio Code (VS Code)
# **VS Code** is a lightweight, flexible code editor that supports Python development with extensions.
#
# 1. Download and install VS Code from [https://code.visualstudio.com/](https://code.visualstudio.com/)
#
# 2. Open VS Code and go to the Extensions Marketplace (icon on the left toolbar).
#
# 3. Search for the Python extension by Microsoft and install it.
#
# 4. Ensure that the correct Python interpreter is selected:
#
# - Press Ctrl+Shift+P (or Cmd+Shift+P on Mac)
#
# - Search for Python: Select Interpreter
#
# - Choose the Python version installed via Anaconda or your system Python
#
# 5. Create a new Python file (.py) and test your setup by running:
#  ```python
#    print("Hello, VS Code!")
#    ```
# 6. You can now write and run Python scripts efficiently, with features like debugging, linting, and code completion.
#   ---
#
# #### 3. Google Colab
# **Google Colab** is a cloud-based Python environment that allows you to write and run code without any installation. It is ideal for beginners or collaborative projects.
#
# 1. Open Google Colab in your browser: https://colab.research.google.com/
#
# 2. Sign in using your Google account.
#
# 3. Create a new notebook by selecting File → New Notebook.
#
# 4. Test Python execution by running:
#
#   ```python
#    print("Hello, Colab!")
#    ```
# 5. Optionally, you can mount your Google Drive to read or save files directly from your Drive:
# ```python
#    from google.colab import drive
#    drive.mount('/content/drive')
#    ```
# 6. Colab also provides free GPU and TPU resources for running intensive computations.
#   ---
#
# ## General Comment
#
# - **Anaconda / Jupyter Notebook** is best for local data science projects and when you need full control over your environment.
#
# - **VS Code** is ideal for script-based development and larger projects with multiple files.
#
# - **Google Colab** is excellent for lightweight projects, sharing notebooks, or running code on powerful cloud resources without installation.
#
# In this module, we will be mostly using  **Anaconda / Jupyter Notebook** and sometimes **VS Code**.

# %% [markdown]
# # Variables and Basic Data Types
# Understanding data types is fundamental for data preprocessing and modelling tasks.
# ### Core Data Types:
# - `int`: integer values
# - `float`: real numbers
# - `str`: text
# - `bool`: boolean values
# - `list`: ordered collection
# - `tuple`: immutable ordered collection
# - `dict`: key-value mapping
#
# To identify each variable data type, use `type () function`.

# %%
# basic variables in python

first_name = 'Tom' #string
last_name = 'Hanks'
country = 'United States'
city = 'Concord, California'
age = 69 #int
is_married = False #bool
skills = ['Comedy Actor', 'Drama Actor', 'Filmmaker'] #list
films=('The Terminal', 'Here', 'A man called Otto') #tuple
person_info = {'firstname': 'Tom', 'lastname': 'Hanks','country': 'United States','city': 'Concord, California'} #dictionary

# %%
# printing data types using type(var) 
print("First name's data type:",type(first_name))
print("Last name's data type:", type(last_name))
print("Country's data type:", type(country))
print("Age's data type:", type(age))
print("Married's data type:", type(is_married))
print("Skills's data type:", type(skills))
print("Films's data type:", type(films))
print("Personal infromation's data type:", type(person_info))
# Out:
# First name's data type: <class 'str'>
# Last name's data type: <class 'str'>
# Country's data type: <class 'str'>
# Age's data type: <class 'int'>
# Married's data type: <class 'bool'>
# Skills's data type: <class 'list'>
# Films's data type: <class 'tuple'>
# Personal infromation's data type: <class 'dict'>

# %%
# printing variables values & string length function
print('First name:', first_name)
print('First name length:', len(first_name))
print('Last name: ', last_name)
print('Last name length: ', len(last_name))
print('Country: ', country)
print('City: ', city)
print('Age: ', age)
print('Married: ', is_married)
print('Skills: ', skills)
print('Films: ', films)
print('Personal information: ', person_info)
# Out:
# First name: Tom
# First name length: 3
# Last name:  Hanks
# Last name length:  5
# Country:  United States
# City:  Concord, California
# Age:  69
# Married:  False
# Skills:  ['Comedy Actor', 'Drama Actor', 'Filmmaker']
# Films:  ('The Terminal', 'Here', 'A man called Otto')
# Personal information:  {'firstname': 'Tom', 'lastname': 'Hanks', 'country': 'United States', 'city': 'Concord, California'}

# %%
# Declaring multiple variables in one line
first_name, last_name, country, age, is_married = 'Tom','Hanks','United States',69,False
print(first_name, last_name, country, age, is_married)
print('First name:', first_name)
print('Last name: ', last_name)
print('Country: ', country)
print('Age: ', age)
print('Married: ', is_married)
# Out:
# Tom Hanks United States 69 False
# First name: Tom
# Last name:  Hanks
# Country:  United States
# Age:  69
# Married:  False

# %%
# Single line comment
letter = 'P'                # A string could be a single character or a bunch of texts
print(letter)               # P
print(len(letter))          # 1
greeting = 'Hello, World!'  
print(greeting)             
print(len(greeting))        
sentence = "I hope you are enjoying today's weather."
print(sentence)
# Out:
# P
# 1
# Hello, World!
# 13
# I hope you are enjoying today's weather.

# %%
# Multiline String
multiline_string = '''I am happy that I am a master student at SRH.
Heidelberg is my second-home.
I have big dreams.'''
print(multiline_string)
# Another way of doing the same thing
multiline_string = """I am happy that I am a master student at SRH.
Heidelberg is my second-home.
I have big dreams."""
print(multiline_string)
# Out:
# I am happy that I am a master student at SRH.
# Heidelberg is my second-home.
# I have big dreams.
# I am happy that I am a master student at SRH.
# Heidelberg is my second-home.
# I have big dreams.

# %%
# String Concatenation
first_name = 'Tom'
last_name = 'Hanks'
space = ' '
full_name = first_name + space + last_name
print(full_name) 
# Checking length of a string using len() builtin function
print(len(first_name)) 
print(len(last_name))  
print(len(first_name) > len(last_name)) 
print(len(full_name))
# Out:
# Tom Hanks
# 3
# 5
# False
# 9

# %%
# Unpacking characters
language = 'Python'
a, b, c, d, e, f = language  # unpacking sequence characters into variables
print(a)  # P
print(b)  # y
print(c)  # t
print(d)  # h
print(e)  # o
print(f)  # n
# Out:
# P
# y
# t
# h
# o
# n

# %%
# Accessing characters in strings by index
language = 'Python'
first_letter = language[0]
print(first_letter)  # P
second_letter = language[1]
print(second_letter)  # y
last_index = len(language) - 1
last_letter = language[last_index]
print(last_letter)  # n
# Out:
# P
# y
# n

# %%
# If we want to start from right end we can use negative indexing. -1 is the last index
language = 'Python' # string is a list of characters
last_letter = language[-1]
print(last_letter)  # n
second_last = language[-2]
print(second_last)  # o
# Out:
# n
# o

# %%
# Slicing
language = 'Python' # string is a list of characters
# starts at zero index and up to 3 but not include 3
first_three = language[0:3]
last_three = language[3:6]
print(last_three)  # hon
# Another way
last_three = language[-3:]
print(last_three)   # hon
last_three = language[3:]
print(last_three)   # hon
# Out:
# hon
# hon
# hon

# %%
# Skipping character while splitting Python strings
"""start (optional) - Starting integer where the slicing of the object starts. Default to None if not provided.
stop - Integer until which the slicing takes place.
step (optional) - Integer value which determines the increment between each index for slicing."""
language = 'Python'
pto = language[0:5:2]
print(pto)  # pto
# Out:
# Pto

# %%
# Escape sequence
print('I hope everyone enjoys the weather today.\n Do you enjoy it ?')  # line break
print('Days\tTopics\tExercises')
print('Day 1\t1\t5')
print('Day 2\t2\t6')
print('Day 3\t3\t4')
print('Day 5\t4\t5')
print('This is a back slash  symbol (\\)')  # To write a back slash
print('In every programming language it starts with \"Hello, World!\"')
# Out:
# I hope everyone enjoys the weather today.
#  Do you enjoy it ?
# Days	Topics	Exercises
# Day 1	1	5
# Day 2	2	6
# Day 3	3	4
# Day 5	4	5
# This is a back slash  symbol (\)
# In every programming language it starts with "Hello, World!"

# %%
# String Methods
# capitalize(): Converts the first character the string to a capital Letter

challenge = 'i am feeling great!'
print(challenge.capitalize())
# Out:
# I am feeling great!

# %%
# count(): returns occurrences of substring in string, count(substring, start=.., end=..)

sports = 'Hi, I am Tim. Today, I will go to the gym. Then, I will play Tennis.'
print("\"T\" occurs" , sports.count('T'), "time(s).")  
print("\"t\" occurs" , sports.count('t'), "time(s).") 
print("\"i\" occurs from the second character till the 15th character", sports.count('i',1,14), "time(s).") 
print("\"th\" occurs" , sports.count('th'), "time(s).")
# Out:
# "T" occurs 4 time(s).
# "t" occurs 2 time(s).
# "i" occurs from the second character till the 15th character 2 time(s).
# "th" occurs 1 time(s).

# %%
# endswith(): Checks if a string ends with a specified ending

sentence = 'Hi, I am Tim.'
print(sentence.endswith('im'))   # False "m."
print(sentence.endswith('tion'))  # False
# Out:
# False
# False

# %%
# expandtabs(): Replaces tab character with spaces, default tab size is 8. It takes tab size argument
sentence = 'Tim\tis\ta\t great\tEngineer.'
print(sentence.expandtabs())   
print(sentence.expandtabs(1))
print(sentence.expandtabs(2)) 
print(sentence.expandtabs(3))
# Out:
# Tim     is      a        great  Engineer.
# Tim is a  great Engineer.
# Tim is  a  great  Engineer.
# Tim   is a   great   Engineer.

# %%
# find(): Returns the index of first occurrence of substring

sentence = 'Tim is a great Engineer.'
print(sentence.find('im'))  # 1
print(sentence.find('e'))  # 11
print(sentence.find('E'))  # 15
print(sentence.find('it'))  # -1
# Out:
# 1
# 11
# 15
# -1

# %%
# format()	formats string into nicer output
first_name = 'Tom'
last_name = 'Hanks'
job = 'actor'
country = 'United Stated'
sentence = 'I am {} {}. I am an {}. I live in the {}.'.format(
    first_name, last_name, job, country)
print(sentence)  

radius = 10
pi = 3.14
area = pi  # radius ## 2
result = 'The area of circle with {} is {}'.format(str(radius), str(area))
print(result)
# Out:
# I am Tom Hanks. I am an actor. I live in the United Stated.
# The area of circle with 10 is 3.14

# %%
# index(): Returns the index of substring
sentence = 'Tim is a great Engineer.'
print(sentence.index('i'))  
print(sentence.index('t'))
# Out:
# 1
# 13

# %%
# isalnum(): Checks alphanumeric character
# Example of characters that are not alphanumeric: (space)!#%&? etc.

sentence = 'TimisagreatEngineer'
print(sentence.isalnum())  # True

sentence = 'Tim is a great Engineer.'

print(sentence.isalnum())  # False

sentence = 'Tim is a great Engineer since 2019.'
print(sentence.isalnum())  # False
# Out:
# True
# False
# False

# %%
# isalpha(): Checks if all characters are alphabets only

sentence = 'TimisagreatEngineer'
print(sentence.isalpha())  # True

sentence =  'Tim is a great Engineer since 2019.'
print(sentence.isalpha())      # False

sentence =  'TimisagreatEngineersince2019.'
print(sentence.isalpha())      # False
# Out:
# True
# False
# False

# %%
# isdigit(): Checks Digit Characters

sentence = 'Thirty'
print(sentence.isdigit())  # False
sentence = '30'
print(sentence.isdigit())   # True
# Out:
# False
# True

# %%
# isdecimal(): Checks if all the characters in a string are decimals (0-9):

num = '10'
print(num.isdecimal())  # True
num = '10.5'
print(num.isdecimal())  # False
# Out:
# True
# False

# %%
# isidentifier():Checks for valid identifier means it check if a string is a valid variable name

sentence = '30YearsOfPrision'
print(sentence.isidentifier())  # False, because it starts with a number
sentence = 'thirty_years_of_prision'
print(sentence.isidentifier())  # True
# Out:
# False
# True

# %%
# islower():Checks if all alphabets in a string are lowercase

sentence = 'thirty years of prision'
print(sentence.islower())  # True
sentence = 'Thirty years of prision'
print(challenge.islower())  # False
# Out:
# True
# True

# %%
# isupper(): returns if all characters are uppercase characters

sentence = 'thirty years of prision'
print(sentence.isupper())  # False
sentence = 'thirty years of prision'
print(sentence.isupper())  # True
# Out:
# False
# False

# %%
# isnumeric():Checks numeric characters

num = '10'
print(num.isnumeric())      # True
print('ten'.isnumeric())    # False
# Out:
# True
# False

# %%
# join(): Returns a concatenated string

names = ['Tom', 'Teresa', 'Tin', 'Tim']
result = 'My friends are \t' + ', '.join(names)
print(result)
# Out:
# My friends are 	Tom, Teresa, Tin, Tim

# %%
# strip(): Removes both leading and trailing characters

sentence = "     great     "
print(sentence)
print("Tim is a",sentence.strip(),"Engineer since 2019.")
# Out:
#      great
# Tim is a great Engineer since 2019.

# %%
# replace(): Replaces substring inside

sentence = 'Tim is a great Engineer'
print(sentence.replace('Tim', 'Sue'))  
print(sentence.replace('tim', 'Sue'))
# Out:
# Sue is a great Engineer
# Tim is a great Engineer

# %%
# split():Splits String from Left

sentence = 'Tim is a great Engineer'
print(sentence.split())
# Out:
# ['Tim', 'is', 'a', 'great', 'Engineer']

# %%
# title(): Returns a Title Cased String
sentence = 'Tim is a great Engineer'
print(sentence.title())
# Out:
# Tim Is A Great Engineer

# %%
# swapcase(): Checks if String Starts with the Specified String

sentence = 'Tim is a great Engineer'
print(sentence.swapcase())   
sentence = 'tim Is a Great engineer'
print(sentence.swapcase())
# Out:
# tIM IS A GREAT eNGINEER
# TIM iS A gREAT ENGINEER

# %%
# startswith(): Checks if String Starts with the Specified String

sentence = 'Tim is a great Engineer'
print(sentence.startswith('Tim')) 
print(sentence.startswith('tim'))
# Out:
# True
# False

# %% [markdown]
# ## Data Type Conversions
# Data science workflows frequently require explicit type casting during data cleaning and preprocessing.
# ### Type Casting Functions
# - `int()`
# - `float()`
# -  `str()`
# -  `bool()`

# %%
age_string= "88"
age=int(age_string)
print(type(age_string))
print(age)
print(type(age))
print(age)
# Out:
# <class 'str'>
# 88
# <class 'int'>
# 88

# %%
num1_float= 44.4
num1= int(num1_float)
print(type(num1_float))
print(num1_float)
print(type(num1))
print(num1)
# Out:
# <class 'float'>
# 44.4
# <class 'int'>
# 44

# %%
num2_float= 44.5
num2= int(num2_float)
print(type(num2_float))
print(num2_float)
print(type(num2))
print(num2)
# Out:
# <class 'float'>
# 44.6
# <class 'int'>
# 44

# %% [markdown]
# ### Arithmetic operations and assigning the result to a variable
# - total = ` a + b`
# - diff = ` a - b`
# - product = ` a * b`
# - division = ` a / b`
# - remainder = ` a % b`
# - floor_division = ` a // b`
# - exponential = ` a ** b`

# %%
# Arithmetic Operations in Python
# Integers
print('Addition: ', 1 + 2)
print('Subtraction: ', 2 - 1)
print('Multiplication: ', 2 * 3)
# Division's / output is a float number
print('Division: ', 4 / 2)
print('Division: ', 6 / 2)
print('Division: ', 7 / 2)
# Division's // output is an integer number
print('Division without the remainder: ', 7 // 2)
print('Division without the remainder: ', 7 // 3)
print('Modulus: ', 3 % 2) # outputs the remainder - largest multiple of 2 is less than 3, thus 3-2=1
print('Exponential: ', 3 ** 2)                     # it is equal to 3 * 3
# Out:
# Addition:  3
# Subtraction:  1
# Multiplication:  6
# Division:  2.0
# Division:  3.0
# Division:  3.5
# Division without the remainder:  3
# Division without the remainder:  2
# Modulus:  1
# Exponential:  9

# %%
# Calculating area of a circle
radius = 10                                 # radius of a circle
# ** operator means power
area_of_circle = 3.14 * radius ** 2
print('Area of a circle:', area_of_circle)
# Out:
# Area of a circle: 314.0

# %%
# Calculating area of a rectangle
length = 10
width = 20
area_of_rectangle = length * width
print('Area of rectangle:', area_of_rectangle)
# Out:
# Area of rectangle: 200

# %%
# Calculating a weight of an object
mass = 75
gravity = 9.81
weight = mass * gravity
print(weight, 'N')
# Out:
# 735.75 N

# %% [markdown]
# ### Boolean Comparison
# A Boolean comparison evaluates a condition and returns either True or False. Thus, the result is always of type bool.
# Here are the following comparison operators:
# - Equal to: `==`
# - Not equal to: `!=`
# - Greater than: `>`
# - Less than: `<`
# - Greater than or equal: `>=`
# - Less than or equal to:`<=`

# %%
# Numeric comparison
print(3 > 2)     # True, because 3 is greater than 2
print(3 >= 2)    # True, because 3 is greater than 2
print(3 < 2)     # False,  because 3 is greater than 2
print(2 < 3)     # True, because 2 is less than 3
print(2 <= 3)    # True, because 2 is less than 3
print(3 == 2)    # False, because 3 is not equal to 2
print(3 != 2)    # True, because 3 is not equal to 2
# Out:
# True
# True
# False
# True
# True
# False
# True

# %%
# String comparison
print(len('mango') == len('avocado'))  # False
print(len('mango') != len('avocado'))  # True
print(len('mango') < len('avocado'))   # True
print(len('milk') != len('meat'))      # False
print(len('milk') == len('meat'))      # True
print(len('tomato') == len('potato'))  # True
print(len('python') > len('dragon'))   # False
# Out:
# False
# True
# True
# False
# True
# True
# False

# %%
# Boolean comparison
print('True == True: ', True == True)
print('True == False: ', True == False)
print('False == False:', False == False)
print('True and True: ', True and True)
print('True or False:', True or False)
# Out:
# True == True:  True
# True == False:  False
# False == False: True
# True and True:  True
# True or False: True

# %%
# Combining comparisons with logical operators
print(3 > 2 and 4 > 3)  # True - because both statements are true
print(3 > 2 and 4 < 3)  # False - because the second statement is false
print(3 < 2 and 4 < 3)  # False - because both statements are false
print(3 > 2 or 4 > 3)  # True - because both statements are true
print(3 > 2 or 4 < 3)  # True - because one of the statement is true
print(3 < 2 or 4 < 3)  # False - because both statements are false
print(not 3 > 2)     # False - because 3 > 2 is true, then not True gives False
print(not True)      # False - Negation, the not operator turns true to false
print(not False)     # True
print(not not True)  # True
print(not not False)  # False
# Out:
# True
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False

# %%
# Chained comparisons
num= 7
print (5 < num < 8)
print (5 < num and num < 8)
print (5 < num and num <= 8)
print (5 < num and num > 8)
print (5 < num or num > 8)
# Out:
# True
# True
# True
# False
# True

# %% [markdown]
# ### Now we are done with week 1's lab content 🎉🎉🎉 ##
# ![Week 1](meme.png)
# ### Let's navigate to Exercise's notebook ⬇️⬇️⬇️
# [Exercise Notebook](Week1_Exercise.ipynb)
