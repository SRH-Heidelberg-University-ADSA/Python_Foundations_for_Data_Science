# %% [markdown]
# # **Section A: Lists**

# %% [markdown]
# ## **Problem A1 (Student Marks)**
#
# **Scenario:**
# You are managing the marks of students in a class. Each student has a single numeric mark, and you want to perform data access, modification, and analysis operations on the list of marks.
#
# **Tasks:**
# 1. **Create a list** of 10 integers representing the marks of students.
#    - Example: `[65, 72, 88, 90, 55, 78, 82, 61, 70, 95]`
#
# 2. **Access and print**:
#    - The **first element** (mark of the first student)
#    - The **last element** (mark of the last student)
#    - The **middle element** (5th element, check the relevant index)
#
# 3. **Append** two new marks to the list and print the updated list.
#
# 4. **Insert** a mark at **index 3** and print the list.
#
# 5. **Remove the lowest mark** from the list using `min()` and `remove()`.
#
# 6. **Reverse the list** using slicing (`[::-1]`) and print it.
#
# 7. **Sort the list** in ascending order and print it.
#
# 8. **Use a list comprehension** to extract marks **greater than or equal to 70** and print the resulting list.
#
# 9. **Compute the average mark** of the class using `sum()` and `len()`.
#
# **Instructions:**
# - Use `append()`, `insert()`, and `remove()` to modify the list.
# - Use slicing and list comprehension for transformations and filtering.
# - Print the list **after each operation** to observe the effect of each step.
# - Ensure the average calculation considers **all current marks in the list**.

# %% [markdown]
# ## **Problem A2 (Shopping Cart)**
#
# **Scenario:**
# You are managing an online shopping cart. Each item has a price, and you need to perform operations such as adding/removing items, calculating totals, and applying discounts.
#
# **Tasks:**
# 1. **Create a list** of 5 product prices (floating-point or integer values).
#    - Example: `[120.0, 80.5, 150.0, 60.0, 90.0]`
#
# 2. **Add 3 new products** to the cart:
#    - Use `append()` to add a single item.
#    - Use `extend()` to add multiple items at once.
#    - Print the updated cart after each addition.
#
# 3. **Remove the most expensive item** from the cart:
#    - Use `max()` to find the highest price.
#    - Use `remove()` to remove it.
#    - Print the cart after removal.
#
# 4. **Calculate the total price** of all items using `sum()` and print it.
#
# 5. **Apply a 10% discount** to all prices using **list comprehension**:
#    - Create a new list with discounted prices.
#    - Print the discounted cart.
#
# **Instructions:**
# - Use `append()` and `extend()` for adding items.
# - Use `max()` and `remove()` for removing items.
# - Use **list comprehension** to apply bulk transformations (like discounts).
# - Print the list/cart **after each step** to track changes.
# - Ensure calculations (total, discount) reflect the **current cart state**.

# %% [markdown]
# ---

# %% [markdown]
# # **Section B: Tuples**

# %% [markdown]
# ## **Problem B1 (Coordinates of Points)**
#
# **Scenario:**
# You are developing a mapping system and need to store fixed coordinates of important landmarks. Tuples are ideal because they are **immutable**, ensuring the coordinates cannot be accidentally changed.
#
# **Tasks:**
# 1. **Create a tuple** containing 5 coordinates as `(x, y)` pairs: `(2,3)`, `(5,6)`, `(1,1)`, `(7,8)`, `(0,0)`.
#
# 2. **Access and print**:
#    - The **second coordinate**
#    - The **last coordinate**
#
# 3. **Concatenate** this tuple with another tuple containing two more coordinates `(10,10)` and `(12,14)`, then print the result.
#
# 4. **Count** how many times the coordinate `(7,8)` appears in the tuple and print the count.
#
# 5. **Find the index** of the coordinate `(5,6)` in the tuple and print it.
#
# **Instructions:**
# - Tuples are **immutable**; you cannot modify individual elements.
# - Use **indexing** to access elements.
# - Use `+` to concatenate tuples.
# - Use `count()` to determine the number of occurrences of a coordinate.
# - Use `index()` to find the position of a specific coordinate.
# - Print the results of each operation clearly so changes can be traced.

# %% [markdown]
# ---

# %% [markdown]
# # **Section C: Sets**

# %% [markdown]
# ## **Problem C1 (Student IDs)**
#
# **Scenario:**
# You have a list of student IDs, but some IDs appear multiple times. You need to manage the IDs efficiently and perform common set operations.
#
# **Tasks:**
# 1. **Convert the list of IDs to a set** to remove duplicates.
#    - Example: `[12, 45, 78, 12, 56, 45, 89]` → convert to `{12, 45, 78, 56, 89}`
#
# 2. **Add a new ID** to the set using `add()` and print the updated set.
#
# 3. **Remove IDs** using:
#    - `remove()` (raises an error if the ID does not exist)
#    - `discard()` (does not raise an error if the ID does not exist)
#
# 4. Perform **set operations** with another set of IDs:
#    - **Union** to combine all IDs
#    - **Intersection**  to find common IDs
#    - **Difference** to find IDs present in the first set but not in the second
#
# 5. Use **set comprehension** to select IDs **greater than 50** and print the resulting set.
#
# **Instructions:**
# - Demonstrate **all common set operations**: addition, removal, union, intersection, difference, and comprehension.
# - Print the state of the set **after each modification** to show changes.
# - Ensure that **set properties** (uniqueness, unordered) are highlighted in your solution.

# %% [markdown]
# ---

# %% [markdown]
# # **Section D: Dictionaries**

# %% [markdown]
# ## **Problem D1 (Product Inventory)**
#
# **Scenario:**
# You are managing a store’s product inventory. Each product has a **name** and a **quantity in stock**. You need to perform operations to update, remove, and sort the inventory.
#
# **Tasks:**
# 1. **Create a dictionary** with product names as keys and quantities as values.
#    - Example:
#      ```python
#      inventory = {
#          "Apples": 50,
#          "Bananas": 30,
#          "Oranges": 20,
#          "Grapes": 15
#      }
#      ```
#
# 2. **Update product quantities**:
#    - Use assignment (`inventory["Apples"] = 60`) to update a single product.
#    - Use `update()` to modify multiple products at once.
#    - Print the dictionary after each update.
#
# 3. **Remove discontinued products** using `pop()` and print the updated inventory.
#
# 4. **Sort products**:
#    - **Alphabetically** by product name using `sorted(inventory.keys())`.
#    - **By quantity** using `sorted(inventory.values())`.
#    - Print the sorted lists for clarity.
#
# **Instructions:**
# - Demonstrate **access, update, removal, and sorting** of dictionary data.
# - Print the dictionary or sorted results **after each operation** to show changes.
# - Highlight how **sorting by key vs sorting by value** works in practice.

# %% [markdown]
# ---
# # **Section E : Nested Lists and Dictionaries**

# %% [markdown]
# ## **Problem E1 (Departments and Employees)**
#
# **Scenario:**
# A company has multiple departments. Each department has a manager and a list of employees. Each employee has a **name** and a **salary**. You are tasked with managing and analysing this data.
#
# **Tasks:**
# 1. **Create a nested dictionary** representing the company structure.
#    - Keys: department names (e.g., "HR", "IT", "Marketing").
#    - Values: dictionaries with:
#      - `"manager"` → a string with the manager’s name.
#      - `"employees"` → a list of dictionaries, each with keys: `"name"` and `"salary"`.
#    - Each department should have 2–3 employees initially.
#
# 2. **Add employees** to any department.
# 3. **Remove employees** who have left from any department.
# 4. **Calculate the average salary** for each department.
# 5. **List employees earning above a threshold** (e.g., 1000) using **nested loops** or **list comprehension**.
#
# **Instructions:**
# - Focus on using **nested dictionaries** for data storage.
# - Demonstrate **adding, removing, and updating** data.
# - Use **loops and comprehensions** for aggregation and filtering.
# - Print results clearly at each step to show changes in the company data.

# %% [markdown]
# ---
# # Final Mini Challenge: Student Event Registration System
#
# ## Scenario
#
# You are asked to help the academic office organise a small university event. Several students have registered for different sessions, including workshops, labs, and talks. The office wants a simple Python program that can organise this information, remove duplicate session names, count registrations, and present the data clearly.
#
# The system should model real-world registration data using Python data structures. Each student has a unique student ID, a name, and a list of sessions that they registered for.
#
# ## Given Data
#
# ```python
# students = [
#     ("S001", "Alice", ["AI Workshop", "Python Lab", "Data Ethics"]),
#     ("S002", "Omar", ["Python Lab", "Cloud Computing"]),
#     ("S003", "Mina", ["AI Workshop", "Data Ethics"]),
#     ("S004", "Lina", ["Python Lab", "AI Workshop"]),
#     ("S005", "David", ["Cloud Computing", "Data Ethics"])
# ]
# ```
# ### Each student is represented as a tuple:
#
# ```python
# (student_id, student_name, registered_sessions)
# ```
#
#
#
#
# ### Exact Tasks
# 1. Extract all session names from all students and store them in a set.
# 2. Print the first and last registered session for each student using list indexing.
# 3. Add "Career Talk" to the registered sessions of every student.
# 4. Add a comment explaining why each student record is stored as a tuple, while the sessions are stored as a list.
# 5. Create a nested dictionary where:
#     - the key is the student ID
#     - the value is another dictionary containing:
#         - the student name
#         - the registered sessions
#         - the total number of registered sessions
# 6. Use set operations to find:
#     - all unique sessions
#     - the sessions shared by Alice and Mina
#     - the sessions registered by Alice but not by Mina
# 7. Print a clear final summary for each student.
#
#
# ### Bonus Questions:
# Refactor the solution so that:
#
# - each task is implemented in a separate function;
# - the event is represented using an appropriate class;
# - each student is represented using an appropriate class;
# - the final program is organised in a clean, reusable, and maintainable way.

# %% [markdown]
# ------
# # Take-Home Assignments
# Complete the following problems at home. See the [submission instructions](https://github.com/SRH-Heidelberg-University-ADSA/Python_Foundations_for_Data_Science/blob/main/SUBMISSION_INSTRUCTIONS.md).

# %% [markdown]
# ## **Problem A (Fibonacci Sequence)**
#
# **Scenario:**
# You are generating Fibonacci numbers, a sequence where each number is the sum of the two preceding numbers. You will store, manipulate, and filter the sequence using **loops and list comprehension**.
#
# **Tasks:**
# 1. **Create a list** to store the first 10 Fibonacci numbers.
#    - Start with the first two numbers: `[0, 1]`.
#
# 2. **Use a loop** to generate the remaining numbers in the sequence until you have 10 numbers in total.
#    - Each new number is the sum of the previous two numbers.
#
# 3. **Reverse the sequence** using **list comprehension** and print the reversed list.
#
# 4. **Extract only even Fibonacci numbers** using a list comprehension with a condition and print the resulting list.
#
# **Instructions:**
# - Use **loops** to build the sequence dynamically.
# - Use **list comprehension** for reversing and filtering.
# - Print **both the original and transformed lists** to visualise each step.
# - Ensure your final list of even numbers only contains Fibonacci numbers that are divisible by 2.

# %% [markdown]
# ## **Problem B (Student Grades Tuple)**
#
# **Scenario:**
# You are storing grades for a student that should remain unchanged. Tuples are ideal because they are **immutable**, preventing accidental modification of the grades.
#
# **Tasks:**
# 1. **Create a tuple** with the student’s grades: `(85, 90, 78, 92, 88)`.
#
# 2. **Print the maximum and minimum grades** using `max()` and `min()`.
#
# 3. **Count** how many times the grade `90` appears in the tuple using `count()`.
#
# 4. **Find the position (index)** of the grade `78` using `index()`.
#
# 5. **Slice the tuple** to extract the **top three grades** (highest three values in order of appearance) and print them.
#
# **Instructions:**
# - Tuples are **immutable**; you cannot modify elements.
# - Use `count()` and `index()` to analyze the tuple.
# - Use **slicing** to access a portion of the tuple.
# - Print the results of each step clearly to trace your operations.
# - Combine **analysis** (max, min, count, index) and **data access** (slicing) in your solution.

# %% [markdown]
# ## **Problem C (Voting System)**
#
# **Scenario:**
# You are managing votes for candidates in an election. Each vote is represented by a candidate ID. You need to track unique votes, compare sets, and filter candidates using set operations.
#
# **Tasks:**
# 1. **Create a set of votes** representing candidate IDs.
#    - Example: `{101, 102, 103, 104}`
#
# 2. **Add new votes** to your set using `add()` or `update()`.
#    - Print the updated set.
#
# 3. **Create another set of votes** representing votes from a different polling station or batch.
#    - Example: `{102, 103, 105, 106}`
#
# 4. **Check subset and superset relationships**:
#    - Determine if the first set is a **subset** of the second set.
#    - Determine if the first set is a **superset** of the second set.
#    - Print the results clearly.
#
# 5. **Filter votes** for candidates with **ID > 100** using **set comprehension** and print the resulting set.
#
# **Instructions:**
# - Focus on **set logic**: addition, comparison, and filtering.
# - Use `add()`, `update()`, and **set comprehension** appropriately.
# - Print results **after each operation** to clearly show the state of the sets.

# %% [markdown]
# ## **Problem D (Employee Records)**
#
# **Scenario:**
# You are managing employee information for a company. Each employee has details like **name, age, department, and salary**. You need to perform dictionary operations to store, modify, and analyse employee data.
#
# **Tasks:**
# 1. **Create a dictionary** with 3 employees.
#    - Each key is an employee ID (or name), and each value is another dictionary containing:
#      - `"name"` → string
#      - `"age"` → integer
#      - `"department"` → string
#      - `"salary"` → integer or float
#    - Example:
#      ```python
#      employees = {
#          "E01": {"name": "Alice", "age": 28, "department": "HR", "salary": 5000},
#          "E02": {"name": "Bob", "age": 32, "department": "IT", "salary": 6000},
#          "E03": {"name": "Charlie", "age": 25, "department": "Marketing", "salary": 4500}
#      }
#      ```
#
# 2. **Add a new employee** using assignment and print the updated dictionary.
#
# 3. **Update an employee's salary** using the `update()` method and print the dictionary.
#
# 4. **Remove an employee** using `pop()` and print the updated dictionary.
#
# 5. **Loop through the dictionary** and print `"Key: Value"` pairs for each employee.
#
# 6. **Create a dictionary comprehension** mapping employee **names** to **salaries** and print the resulting dictionary.
#
# **Instructions:**
# - Use **dictionary methods** (`update()`, `pop()`) for modifications.
# - Use **iteration** to display dictionary contents.
# - Use **dictionary comprehension** for mapping or transformations.
# - Print results **after each operation** to clearly track changes in the data.

# %% [markdown]
# ## **Problem E (Class Marks Matrix)**
#
# **Scenario:**
# You are managing the marks of students in multiple subjects. Each student has scores in three subjects, and you want to perform data access, transformations, and calculations.
#
# **Tasks:**
# 1. **Create a nested list** representing the marks of 3 students.
#    - Each student is represented by a list of 3 subject marks (integers).
#    - Example structure:
#      ```python
#      marks = [
#          [85, 90, 78],  # Student 1
#          [88, 92, 80],  # Student 2
#          [75, 85, 89]   # Student 3
#      ]
#      ```
#
# 2. **Access the second mark of the second student** using nested indexing and print it.
#
# 3. **Reverse each student’s marks** using **list comprehension** and print the updated nested list.
#
# 4. **Calculate the sum and average** of all marks in the class.
#    - Use nested loops or **nested comprehension** to flatten and sum the marks.
#    - Compute the average by dividing the total by the total number of marks.
#
# **Instructions:**
# - Focus on **nested indexing** to access individual elements.
# - Use **list comprehension** to transform each student’s marks.
# - Print intermediate steps clearly to show the effect of each operation.
# - Ensure calculations consider all students and all subjects.

# %% [markdown]
# ### Well done, Week 3 Exercises Complete 🎉!
#
# - Don't forget to submit your [exercise notebook](Week3_Exercise.ipynb) on your private GitHub Repository (see [submission instructions](https://github.com/SRH-Heidelberg-University-ADSA/Python_Foundations_for_Data_Science/blob/main/SUBMISSION_INSTRUCTIONS.md)). The deadline is 06.05.2026 @ 23:59.
#
# - See you next time when we dive into `Functions & Modular Programming`!
